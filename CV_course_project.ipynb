# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
# !nvidia-smi
# Out:
# Mon May 12 08:03:20 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   41C    P8             15W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
HOME = "/content"
print(HOME)
# Out:
# /content

# %% [markdown]
# ###Clonning

# %%
# !git clone https://github.com/WongKinYiu/yolov9.git

# %cd yolov9
# !pip install -r requirements.txt -q
# %cd ..
# Out:
# fatal: destination path 'yolov9' already exists and is not an empty directory.
# /content/yolov9
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 116.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 105.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 59.6 MB/s eta 0:00:00

# %%
# !pip install -q roboflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 45.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 136.3 MB/s eta 0:00:00

# %%
from roboflow import Roboflow

from IPython.display import Image

# %%
# !mkdir -p {HOME}/weights

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !mkdir -p {HOME}/data

# %%
SOURCE_IMAGE_PATH = f"{HOME}/data/TEST.jpg"

# %%
# !python detect.py --weights {HOME}/weights/gelan-c.pt --conf 0.1 --source {SOURCE_IMAGE_PATH} --device 0
# Out:
# detect: weights=['/content/weights/gelan-c.pt'], source=/content/data/TEST.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLO 🚀 v0.1-104-g5b1ea9a Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
#
# Fusing layers...
# Model summary: 387 layers, 25288768 parameters, 0 gradients, 102.1 GFLOPs
# image 1/1 /content/data/TEST.jpg: 640x640 4 boats, 16.1ms
# Speed: 0.6ms pre-process, 16.1ms inference, 125.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp10

# %%
Image(filename=f"{HOME}/yolov9/runs/detect/exp10/TEST.jpg", width=500, height=400)

# %%
# !python detect.py --weights {HOME}/weights/yolov9-c.pt --conf 0.1 --source {SOURCE_IMAGE_PATH}
# Out:
# detect: weights=['/content/weights/yolov9-c.pt'], source=/content/data/TEST.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLO 🚀 v0.1-104-g5b1ea9a Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
#
# Fusing layers...
# Model summary: 604 layers, 50880768 parameters, 0 gradients, 237.6 GFLOPs
# image 1/1 /content/data/TEST.jpg: 640x640 4 boats, 25.4ms
# Speed: 0.6ms pre-process, 25.4ms inference, 210.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp15

# %%
Image(filename=f"{HOME}/yolov9/runs/detect/exp15/TEST.jpg", width=500, height=400)

# %%
from google.colab import userdata

ROBOFLOW_API_KEY = userdata.get('ROBOFLOW_API_KEY')

rf = Roboflow(api_key=ROBOFLOW_API_KEY)
project = rf.workspace("edu-hbaro").project("tanks-efpvv")
version = project.version(10)
dataset = version.download("yolov9")

# %%
# !python train.py \
--batch 8 --epochs 10 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data {dataset.location}/data.yaml \
--weights {HOME}/weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747056453.289334   58393 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747056453.296001   58393 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# ...

# %%
# !python val.py \
--img 640 --batch 8 --conf 0.001 --iou 0.7 --device 0 \
--data {dataset.location}/data.yaml \
--weights {HOME}/yolov9/runs/train/exp3/weights/best.pt
# Out:
# val: data=/content/yolov9/Tanks-10/data.yaml, weights=['/content/yolov9/runs/train/exp3/weights/best.pt'], batch_size=8, imgsz=640, conf_thres=0.001, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False, min_items=0
# YOLO 🚀 v0.1-104-g5b1ea9a Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
#
# Fusing layers...
# gelan-c summary: 387 layers, 25227859 parameters, 0 gradients, 101.8 GFLOPs
# val: Scanning /content/yolov9/Tanks-10/valid/labels.cache... 43 images, 5 backgrounds, 0 corrupt: 100% 43/43 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  17% 1/6 [00:00<00:02,  1.77it/s]Exception in thread Thread-3 (plot_images):
# Traceback (most recent call last):
# ...

# %%
# !python detect.py \
--img 640 --conf 0.1 --device 0 \
--weights {HOME}/yolov9/runs/train/exp3/weights/best.pt \
--source {dataset.location}/valid/images
# Out:
# detect: weights=['/content/yolov9/runs/train/exp3/weights/best.pt'], source=/content/yolov9/Tanks-10/valid/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLO 🚀 v0.1-104-g5b1ea9a Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
#
# Fusing layers...
# gelan-c summary: 387 layers, 25227859 parameters, 0 gradients, 101.8 GFLOPs
# image 1/43 /content/yolov9/Tanks-10/valid/images/1504717585_image_jpg.rf.c398e82329c72a0f26bf803d47bb343e.jpg: 640x640 1 0, 15.6ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/yolov9/runs/detect/exp17/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
# !python detect.py \
--img 640 --conf 0.1 --device 0 \
--weights {HOME}/yolov9/runs/train/exp3/weights/best.pt \
--source {SOURCE_IMAGE_PATH}
# Out:
# detect: weights=['/content/yolov9/runs/train/exp3/weights/best.pt'], source=/content/data/TEST.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLO 🚀 v0.1-104-g5b1ea9a Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
#
# Fusing layers...
# gelan-c summary: 387 layers, 25227859 parameters, 0 gradients, 101.8 GFLOPs
# image 1/1 /content/data/TEST.jpg: 640x640 3 0s, 15.8ms
# Speed: 0.6ms pre-process, 15.8ms inference, 199.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp18

# %%
Image(filename=f"{HOME}/yolov9/runs/detect/exp18/TEST.jpg", width=500, height=400)

# %% [markdown]
# На этом этапе я попытался использовать обученную модель best.pt, но оно не работает с ultralytis. Поэтому решл натренировать модель на ultralytics.

# %%
from ultralytics import YOLO

model = YOLO("yolov9s.pt")
model.info()

results = model.train(data="/content/yolov9/Tanks-10/data.yaml", epochs=25, imgsz=640, batch=25)
print(results)
# Out:
# YOLOv9s summary: 544 layers, 7,318,368 parameters, 0 gradients, 27.6 GFLOPs
# New https://pypi.org/project/ultralytics/8.3.132 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
# ...
